# %% [markdown]
# # Histogram Equalization

# %% [markdown]
# ### imports

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import random

# %% [markdown]
# ### main variables

# %%
image_path = 'images/hawkes.jpg'

G = 256

# %% [markdown]
# ### functions

# %%
#Source: https://stackoverflow.com/a/42314798

def plotimage(img, title=None, figsize=None):
    h = img.shape[0]
    w = img.shape[1]
    dpi = 80
    if figsize is None:
        figsize = w / float(dpi), h / float(dpi)
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])    
    ax.axis('off')
    ax.imshow(img, cmap='gray')
    if title:
        plt.title(title)
    plt.show()

# %%
def histogram(gray):
    hist = np.array([0]*G)
    c=0
    for row in gray:
        for pixel in row:       
            hist[pixel]+=1
    return hist

# %%
def plot_histogram(hist, width=0.5, figsize=(15,5), xlabel='Color', ylabel='Intensity', title='Histogram'):
    plt.figure(figsize=figsize)
    plt.bar(list(range(len(hist))),hist,width=width)
    plt.ylabel(xlabel)
    plt.xlabel(ylabel)
    plt.title(title)

    plt.show()

# %% [markdown]
# ### Read Image

# %%
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plotimage(gray, 'Grayscale Image')

# %% [markdown]
# ### Histogram

# %%
hist = histogram(gray)

# %%
plot_histogram(hist)

# %% [markdown]
# ### Cumulative Histogram

# %%
hist_cum = hist.copy()
for i in range(len(hist)-1):
    hist_cum[i+1]+=hist_cum[i]


plot_histogram(hist_cum,title='Cumulative Histogram')

# %% [markdown]
# ### Equalization

# %%
t = np.round((G-1)/(gray.shape[0]*gray.shape[1])*hist_cum)

output = gray.copy()

for i in range(gray.shape[0]):
    for j in range(gray.shape[1]):
        output[i,j] = t[output[i,j]]

print("before")
plotimage(gray)
print("after")
plotimage(output)
# Out:
# before
# after

# %%
hist_after = histogram(output)
plot_histogram(hist_after, title="Equalized Histogram")
