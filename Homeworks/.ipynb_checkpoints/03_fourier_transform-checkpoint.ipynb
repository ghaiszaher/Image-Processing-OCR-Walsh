# %% [markdown]
# # Fourier Transformation

# %% [markdown]
# ### Imports

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import random

# %%
import sys
sys.version
# Out:
# '3.7.1 (default, Dec 14 2018, 19:28:38) \n[GCC 7.3.0]'

# %% [markdown]
# ### main variables

# %%
image_path = "../images/aina_medium.jpg"

# %% [markdown]
# ### functions

# %%
#Source: https://stackoverflow.com/a/42314798

def plotimage(img, title=None, figsize=None, invert=False):
    if invert:
        img = np.max(img) - img.copy()
        
    h = img.shape[0]
    w = img.shape[1]
    dpi = 80
    if figsize is None:
        figsize = w / float(dpi), h / float(dpi)
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])    
    ax.axis('off')
    ax.imshow(img, cmap='gray')
    if title:
        plt.title(title)
    plt.show()

# %% [markdown]
# ### code

# %%
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plotimage(img)

# %% [markdown]
# ### fourier

# %%
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)

#for plotting
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.figure(figsize=(20,20))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Filtering

# %%
def get_filter(r,c, w0='50', w1=None, mode='lpf'):
    pf = np.zeros_like(f_shifted, dtype='uint8')
    cv2.circle(lpf,(ccol,crow),w0,1, -1)
    if mode == 'lpf':
        return pf
    if mode == 'hpf':
        return 1-pf
    if mode == 'bpf':

# %%
def pass_filter(f_shifted, w0, mode='lpf'):
    rows, cols = f_shifted.shape
    crow,ccol = rows//2 , cols//2
    
    f_shifted = f_shifted.copy();
    
    w0 = min(min(f.shape[0], f.shape[1]), w0)
    pf = get_filter(mode)
    
    f_shifted = f_shifted*pf;
    return f_shifted

# %%
def HPF(f_shifted, w0=50):
    rows, cols = f_shifted.shape
    crow,ccol = rows//2 , cols//2
    
    f_shifted = f_shifted.copy();
    
    w0 = min(min(f.shape[0], f.shape[1]), w0)
    
    lpf = np.ones_like(f_shifted, dtype='uint8')
    cv2.circle(lpf,(ccol,crow),w0,0, -1)
    f_shifted = f_shifted*lpf;
    return f_shifted

# %%
def LPF(f_shifted, w0=50):
    f_shifted = f_shifted.copy();
    if w0==0:
        

    rows, cols = f_shifted.shape
    crow,ccol = rows//2 , cols//2
    
    
    w0 = min(min(f.shape[0], f.shape[1]), w0)
    
    lpf = np.ones_like(f_shifted, dtype='uint8')
    cv2.circle(lpf,(ccol,crow),w0,0, -1)
    lpf = 1-lpf
    f_shifted = f_shifted*lpf;
    return f_shifted

# %%
def BPF(f_shifted, w1=50,w2=100):
    return LPF(HPF(f_shifted, w1), w2)

# %% [markdown]
# ### Inverse Fourier

# %%
fshift_filtered = BPF(fshift,10,100)

f_ishift = np.fft.ifftshift(fshift_filtered)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)

plt.figure(figsize=(20,20))
magnitude_spectrum = 20*np.log(np.abs(fshift_filtered))
plt.subplot(121),plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('HPF'), plt.xticks([]), plt.yticks([])

plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
plt.title('Image after HPF'), plt.xticks([]), plt.yticks([])

plt.figure(figsize=(20,20))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])

plt.subplot(122),plt.imshow(img_back)
plt.title('Result in JET'), plt.xticks([]), plt.yticks([])


plt.show()
# Out:
# /home/ghais/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
