# %% [markdown]
# # Characters Segmentation

# %% [markdown]
# ### imports

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import random
import json
from mylib import *

# %% [markdown]
# ### main variables

# %%
image_path = '../images/04.png'
walsh_path = '../res/walsh.json'
db_path = '../res/database.json'
expected_path = '../images/04.expected'
white = 0
black = 1
thresh = 250
blue=(255,255,0)
green=(0,255,0)
red=(0,255,255)
violet=(155,205,155)

# %% [markdown]
# ### Read Image

# %%
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plotimage(gray, 'GrayScale', invert=False)

# %% [markdown]
# ## Convert to Black and White

# %%
bw=1-gray_to_bw(gray, thresh)//255
plotimage(bw, 'B&W', figsize=(15,15))

# %% [markdown]
# ### Vertical Segmentation

# %%
lines = vert_seg(bw)
vert = 255*bw.copy()
vert = cv2.cvtColor(vert, cv2.COLOR_GRAY2RGB)
draw_vert_lines(vert, lines)
plotimage(vert, 'Vertical')

# %% [markdown]
# ### Horizontal Segmentation

# %%
i = 0
start = 0

for line in lines:
    img = bw[line['start']:line['end'],:]
    line['chars'] = hor_seg(img)

hor = vert.copy()
for line in lines:
    start = line['start']
    end = line['end']
    draw_hor_lines(hor, line['chars'], start, end)

plotimage(hor, 'Horizontal')

# %% [markdown]
# ## Plotting Some Random chars

# %%
for k in range(10):
    i = random.randint(0,len(lines)-1)
    line = lines[i]
    j = random.randint(0,len(line['chars'])-1)
    char = line['chars'][j]
    
    img = bw[line['start']:line['end'],char['start']:char['end']]
    
    plotimage(img,'',(2,2))

# %% [markdown]
# ### Vertical Segmentation for every Char

# %%
for line in lines:
    for char in line['chars']:
        img = bw[line['start']:line['end'],char['start']:char['end']]
        char['vertical_parts'] = vert_seg(img)

# %%
for k in range(10):
    i = random.randint(0,len(lines)-1)
    line = lines[i]
    j = random.randint(0,len(line['chars'])-1)
    char = line['chars'][j]
    
    img = 255*bw[line['start']:line['end'],char['start']:char['end']]
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR) 
    
    draw_vert_lines(img, char['vertical_parts'])
            
    img = draw_borders(img, color=violet)
#     img = draw_borders(img, color=0)
    print(char['vertical_parts'])
    plotimage(img,'', (2,2))
# Out:
# [{'start': 0, 'end': 26}]
# [{'start': 9, 'end': 26}]
# [{'start': 9, 'end': 26}]
# [{'start': 9, 'end': 26}]
# [{'start': 9, 'end': 26}]
# [{'start': 22, 'end': 26}]
# [{'start': 0, 'end': 39}]
# [{'start': 9, 'end': 26}]
# [{'start': 0, 'end': 26}]
# [{'start': 0, 'end': 4}, {'start': 9, 'end': 26}]

# %% [markdown]
# ## Walsh-Functions

# %% [markdown]
# ### Read walsh functions

# %%
with open(walsh_path) as f:
    s = f.read()
walsh_list = json.loads(s)
walsh = []
for l in walsh_list:
    walsh.append(np.array(l))

# %% [markdown]
# ### Calculcate Walsh Vectors

# %%
c = 7 #samples to plot

for line in lines:
    for char in line['chars']:
        start=line['start']
        end=line['end']
        
        if char['vertical_parts'] and len(char['vertical_parts'])>0:
            start=line['start']+char['vertical_parts'][0]['start']
            end=line['start']+char['vertical_parts'][-1]['end']
                    
        img = bw[start:end,char['start']:char['end']]
        img = img.copy()
        if 0 in img.shape:
# Walsh= [2609, 4349, 4143, 4435, 3709, 4033, 4079, 4371, 3875, 3767, 3913, 3981, 4051, 4143, 3965, 4033, 4167, 4171, 3833, 3861, 4147, 4159, 3921, 3949, 3869, 4049, 4055, 4059, 4069, 4049, 4027, 4031, 5073, 3693, 4031, 4099, 4077, 4113, 3999, 4067, 4215, 4379, 4157, 4145, 4015, 3979, 4137, 4125, 4167, 4203, 4009, 4021, 4091, 4119, 4025, 4037, 4201, 4077, 4035, 4087, 4033, 4109, 4039, 4091]
# Walsh= [2153, 4019, 3585, 4039, 3861, 4271, 3837, 4251, 3917, 4047, 4101, 4027, 4121, 4091, 4145, 4111, 4227, 4321, 4219, 4301, 4115, 4153, 4123, 4173, 4147, 3921, 3963, 3941, 4027, 4049, 4003, 4029, 5321, 4027, 3889, 4007, 3957, 4095, 3981, 4115, 4209, 4051, 4025, 4071, 4133, 4159, 4109, 4139, 4107, 4145, 4115, 4165, 4091, 4161, 4083, 4141, 3951, 4077, 4135, 4057, 4111, 4013, 4135, 4033]

# %% [markdown]
# ### Vector Comparison

# %%
vecs = []
for k in range(2):
    i = np.random.randint(0, len(lines))
    j = np.random.randint(0, len(lines[i]['chars']))
    if k==0:
        i,j=1,1
    char = lines[i]['chars'][j]
    line_start = lines[i]['start']
    line_end = lines[i]['end']
    char_start = char['start']
    char_end = char['end']
    
    plt.subplot(121+k), plt.imshow(1-bw[line_start:line_end,char_start:char_end], cmap='gray')
    vecs.append(char['walsh_vector'])
    
print("Distance =", distance(vecs[0], vecs[1]))
    
# v1 = lines[1]['chars'][0]['walsh_vector']
# v2 = lines[1]['chars'][5]['walsh_vector']

# inner_prod(v1, v2)
# Out:
# Distance = 12940

# %% [markdown]
# ## Read Database

# %%
with open(db_path) as f:
    db = json.loads(f.read())

# %% [markdown]
# ### Compare Letters to Database

# %%
plotimage(bw, 'B&W', figsize=(15,15))
prediction = ""
for i in range(len(lines)):
    for j in range(len(lines[i]['chars'])):
    #     i = np.random.randint(0, len(lines))
    #     j = np.random.randint(0, len(lines[i]['chars']))
    #     if k==0:
    #         i,j=1,1
        char = lines[i]['chars'][j]
        line_start = lines[i]['start']
        line_end = lines[i]['end']
        char_start = char['start']
        char_end = char['end']

#         plotimage(bw[line_start:line_end,char_start:char_end], figsize=(2,2))
        min_dist = -1
        min_letter = 'NaN'
        for letter in db:
            dist = distance(letter['walsh_vector'], char['walsh_vector'])
            if min_dist == -1 or dist < min_dist:
                min_dist = dist
                min_letter = letter['character']
        char['prediction']=min_letter
        prediction+=min_letter
#         print(min_letter, end='')
#     print()
    prediction+="\n"
print(prediction)
# Out:
# Etymology
# Mainarticle:NameofHungary
# The'.H.'inthenameofHungary(andLatinHungaria)ismostlike1y
# duetoear1yfoundedhistoricalassociationswiththeHuns,whohad
# settledHungarypriortotheAvars.Therestofthewordcomesftom
# theLatinizedformofByzantineGreekOungroi.Accordingtoan
# exp1anation,theGreeknamewasborrowedftomO1d
# Bulgarianagrinu,inturnborrowedftomOghur.TurkicOnogur(.ten
# [tribesofthe]Ogurs.).Onogurwastheco1lectivenameforthetribes
# wholaterjoinedtheBulgartribalconfederacythatruledtheeastern
# partsofHungaryaftertheAvars.[46][47]

# %% [markdown]
# ### Save result in a json file

# %%
s = json.dumps({"image_path": image_path, "threshold": thresh, "lines":lines}, indent=2)
with open(image_path+'.lines.json', 'w') as f:
    f.write(s)

# %% [markdown]
# # Calculate Prediction Accuracy

# %%
with open(expected_path) as f:
    expectation = f.read()

print("Expectation:")
print("-"*20)
print(expectation)
print("="*50, end="\n\n")
print("Prediction:")
print("-"*20)
print(prediction)
# Out:
# Expectation:
# --------------------
# Etymology
# Main article: Name of Hungary
# The "H" in the name of Hungary (and Latin Hungaria) is most likely
# due to early founded historical associations with the Huns, who had
# settled Hungary prior to the Avars. The rest of the word comes from
# the Latinized form of Byzantine Greek Oungroi. According to an
# explanation,the Greek name was borrowed from Old
# Bulgarian agrinu, in turn borrowed from Oghur-Turkic Onogur ('ten
# [tribes of the] Ogurs'). Onogur was the collective name for the tribes
# who later joined the Bulgartribal confederacy that ruled the eastern
# parts of Hungary after the Avars.[46][47]
# ==================================================
#
# Prediction:
# --------------------
# Etymology
# Mainarticle:NameofHungary
# The'.H.'inthenameofHungary(andLatinHungaria)ismostlike1y
# duetoear1yfoundedhistoricalassociationswiththeHuns,whohad
# settledHungarypriortotheAvars.Therestofthewordcomesftom
# theLatinizedformofByzantineGreekOungroi.Accordingtoan
# exp1anation,theGreeknamewasborrowedftomO1d
# Bulgarianagrinu,inturnborrowedftomOghur.TurkicOnogur(.ten
# [tribesofthe]Ogurs.).Onogurwastheco1lectivenameforthetribes
# wholaterjoinedtheBulgartribalconfederacythatruledtheeastern
# partsofHungaryaftertheAvars.[46][47]

# %% [markdown]
# ### Ignore Spaces

# %%
exp = expectation.replace(" ","")

# %%
from difflib import Differ
from termcolor import colored

d = Differ()

diff = list(d.compare(prediction, exp))
errors = 0
for c in diff:
    if c[0]=='+':
        print(colored(c[-1],'blue'), end="")
        errors+=1
    elif c[0]=='-':
        print(colored(c[-1],'red'), end="")
        errors+=1
    else:
        print(colored(c[-1],'green'), end="")
print("="*50)
errors//=2
total = len([x for x in exp if x != '\n'])
print("Errors: {}/{}".format(errors, total))
print("Accuracy= {}%".format(round((1-errors/total)*100,3)))
# Out:
# Etymology
# Mainarticle:NameofHungary
# The"'.H".'inthenameofHungary(andLatinHungaria)ismostlike1ly
# duetoear1lyfoundedhistoricalassociationswiththeHuns,whohad
# settledHungarypriortotheAvars.Therestofthewordcomesftrom
# theLatinizedformofByzantineGreekOungroi.Accordingtoan
# exp1lanation,theGreeknamewasborrowedftromO1ld
# Bulgarianagrinu,inturnborrowedftromOghur.-TurkicOnogur(.'ten
# [tribesofthe]Ogurs.').Onogurwastheco1llectivenameforthetribes
# wholaterjoinedtheBulgartribalconfederacythatruledtheeastern
# partsofHungaryaftertheAvars.[46][47]
# ==================================================
# Errors: 14/506
# Accuracy= 97.233%
